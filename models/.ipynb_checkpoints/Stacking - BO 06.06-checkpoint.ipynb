# %%
import os
import time
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import log_loss
from bayes_opt import BayesianOptimization

from models_utils_skf import *

# %%
def load_oof(mode = 'train'):
    src = '/media/w/1c392724-ecf3-4615-8f3c-79368ec36380/DS Projects/Kaggle/Quora/scripts/models/OOF_preds/'
    oof_preds = pd.DataFrame()
    files = sorted([x for x in os.listdir(src + '{}/'.format(mode)) if '.pkl' in x or '.csv' in x
                   and 'stack' not in x])
    print('\n', 'Loading OOF preds:', files, '\n', 'Numer of files to load:', len(files), '\n')
    for i in files:
        if 'pkl'in i:
            df_preds = pd.read_pickle('{}/{}/{}'.format(src, mode, i))
            if 'id' in df_preds.columns:
                df_preds.drop(['id'], axis = 1, inplace = True)
            if 'test_id' in df_preds.columns:
                df_preds.drop(['test_id'], axis = 1, inplace = True)
        if '.csv'in i:
            df_preds = pd.read_csv('{}/{}/{}'.format(src, mode, i))
            if 'id' in df_preds.columns:
                df_preds.drop(['id'], axis = 1, inplace = True)
            if 'test_id' in df_preds.columns:
                df_preds.drop(['test_id'], axis = 1, inplace = True)
        oof_preds = pd.concat([oof_preds, df_preds], axis = 1)
    return oof_preds

def transform(x):
    a = 0.165 / 0.37
    b =  (1 - 0.165) / (1 - 0.37)
    xt = a * x / (a * x + b * (1 - x))
    return xt

def inv_pred_transform(preds):
    a = 0.165 / 0.37
    b = (1 - 0.165) / (1 - 0.37)
    return b * preds / (b * preds + a * (1 - preds))

def testOOF_transform(X_test2):
    X_test = X_test2.copy()
    for i in range(X_test.shape[1]):
        X_test.iloc[:, i] = X_test.iloc[:, i].apply(inv_pred_transform)
    return X_test

def predict_test_lgbm(test_preds, model_name, transform_preds = True):
    print('Predicting on test set with LightGBM.')
    sub_src = '/media/w/1c392724-ecf3-4615-8f3c-79368ec36380/DS Projects/Kaggle/Quora/submissions/'
    sample_sub = pd.read_csv(sub_src + 'sample_submission.csv')
    sample_sub['is_duplicate'] = test_preds
    if transform_preds:
        sample_sub.is_duplicate = sample_sub.is_duplicate.apply(transform)
    sample_sub.to_csv(sub_src + '{}.csv'.format(model_name), index = False)
    return

# %%
def lgb_foldrun_BO(max_depth, min_data_in_leaf, subsample, colsample_bytree, feature_fraction):
    
    skf = StratifiedKFold(n_splits = 10, random_state = 111, shuffle = True)
    params = {
        'task' : 'train',
        'boosting_type' : 'gbdt',
        'objective' : 'binary',
        'metric' : {'binary_logloss'},
        'learning_rate' : 0.01,
        'feature_fraction' : max(min(feature_fraction, 1), 0),
        'bagging_fraction': 0.9,
        'bagging_freq': 100,
        'num_leaves' : 255,
        'max_depth': int(max_depth),
        'min_data_in_leaf': int(min_data_in_leaf),
        'subsample': max(min(subsample, 1), 0),
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'silent': 1,
        'random_state': 1337,
        'verbose': 1,
        'nthread': 4,
    }
    i = 1
    losses = []
    oof_train = np.zeros((X.shape[0]))
    for tr_index, val_index in skf.split(X, y):
        X_tr, X_val = X[tr_index], X[val_index]
        y_tr, y_val = y[tr_index], y[val_index]
        t = time.time()
        
        lgb_train = lgb.Dataset(X_tr, y_tr)
        lgb_val = lgb.Dataset(X_val, y_val)
        print('Start training on fold: {}'.format(i))
        gbm = lgb.train(params, lgb_train, num_boost_round = 100000, valid_sets = lgb_val,
                        early_stopping_rounds = 200, verbose_eval = False)
        print('Start predicting...')
        val_pred = gbm.predict(X_val, num_iteration=gbm.best_iteration)
        oof_train[val_index] = val_pred
        score = log_loss(y_val, val_pred)
        losses.append(score)
        print('Final score for fold {} :'.format(i), score, '\n')
        i += 1
    print('Mean logloss for model in 10-folds SKF:', np.array(losses).mean(axis = 0))
    return -np.array(losses).mean(axis = 0)

# %%
agbm = np.load('OOF_preds/h2o_gbm_test.npy')
agbm = agbm.T
agbm2 = np.apply_along_axis(transform, 1, agbm)
agbm3 = agbm2.mean(axis = 1)
agbm3 = pd.DataFrame(agbm3)
agbm3.columns = ['is_duplicate_AlexGBM']
agbm3.to_pickle('OOF_preds/test_preds_GBMAlex.pkl')

# %% [markdown]
# Step |   Time |      Value |   colsample_bytree |   feature_fraction |   max_depth |   min_data_in_leaf |   subsample |
#
# 1 | 06m13s |   -0.17474 |             0.6913 |             0.6128 |      3.7855 |            10.9742 |      0.7600 |

# %%
X = load_oof()
y = pd.read_pickle('y_train.pkl')

if isinstance(X, pd.core.frame.DataFrame):
    X = X.values
if isinstance(y, pd.core.frame.DataFrame):
    y = y.is_duplicate.values
if isinstance(y, pd.core.frame.Series):
    y = y.values

lgbBO = BayesianOptimization(lgb_foldrun_BO, {
        'max_depth': (2, 5),
        'min_data_in_leaf': (5, 25),
        'subsample': (0.6, 0.88),
        'colsample_bytree': (0.4, 0.75),
        'feature_fraction': (0.4, 0.85),
    })

num_iter = 15
init_points = 15
lgbBO.maximize(init_points=init_points, n_iter=num_iter)
print('lgb: %f' % lgbBO.res['max']['max_val'])
# Out:
#  Loading OOF preds: ['train_preds_866cols_xgbparams1.pkl', 'train_preds_866cols_xgbparams2.pkl', 'train_preds_866cols_xgbparams3.pkl', 'train_preds_866cols_xgbparams4.pkl', 'train_preds_AttentionClean_preds.pkl', 'train_preds_AttentionNER_preds.pkl', 'train_preds_MLP_1sttry.pkl', 'train_preds_lgb_0.1807_20170603_1943.csv', 'train_preds_lgb_0.1842_20170527_1246.csv', 'train_preds_newNetworks_currentBest.pkl', 'train_preds_xgb_0.1800_20170601_1113.csv', 'train_preds_xgb_0.1808_20170602_0246.csv', 'train_preds_xgb_0.1812_20170603_0506.csv', 'train_preds_xgb_0.1813_20170530_0249.csv']
#  Numer of files to load: 14
#
# Initialization
# ------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   feature_fraction |   max_depth |   min_data_in_leaf |   subsample |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171137294402
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.178977827275
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173393233493
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172238288276
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.177838332617
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175764276313
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.174883213426
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171491921625
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.17558063925
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176132835656
#
# Mean logloss for model in 10-folds SKF: 0.174743786233
#     1 | 06m13s |   -0.17474 |             0.6913 |             0.6128 |      3.7855 |            10.9742 |      0.7600 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171267837019
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.178916841312
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.17370726553
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172501604026
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0
|
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171412259062
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.178947174649
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.17369954741
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172555599431
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.177872869835
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175848432284
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.174998676306
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171684288619
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175647007319
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176345368805
#
# Mean logloss for model in 10-folds SKF: 0.174901122372
#    23 | 04m50s |   -0.17490 |             0.5535 |             0.4374 |      4.8727 |            10.8365 |      0.7353 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171260826187
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.179104763763
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173533798823
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172386283727
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.178289691549
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175623284721
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.175153552645
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171588410539
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.17576035117
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176187271729
#
# Mean logloss for model in 10-folds SKF: 0.174888823485
#    24 | 06m04s |   -0.17489 |             0.6654 |             0.5659 |      2.0880 |            13.9513 |      0.7043 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171274789787
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.178954639668
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173516796115
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172416788972
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.17774110534
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175688640558
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.174747996187
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171548487215
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175532138988
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176302851372
#
# Mean logloss for model in 10-folds SKF: 0.17477242342
#    25 | 06m01s |   -0.17477 |             0.7291 |             0.6425 |      4.4949 |            14.8814 |      0.8154 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171152669181
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.17899996903
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173488450755
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172287754158
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.178105361753
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175800221171
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.174879180642
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171515918124
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175587306814
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176181041333
#
# Mean logloss for model in 10-folds SKF: 0.174799787296
#    26 | 05m56s |   -0.17480 |             0.5478 |             0.8035 |      3.2902 |            16.0273 |      0.8725 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171187360394
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.178991583037
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173558793797
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.1722224942
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.178118920481
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175762486006
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.174823844583
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171532027098
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175571067619
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176162435644
#
# Mean logloss for model in 10-folds SKF: 0.174793101286
#    27 | 05m41s |   -0.17479 |             0.7032 |             0.5292 |      3.2754 |            14.0301 |      0.8640 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171329806342
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.179101342843
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173816234176
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172464515221
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.178049306416
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175689417442
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.175028610553
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171622891087
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175860797888
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176243917163
#
# Mean logloss for model in 10-folds SKF: 0.174920683913
#    28 | 05m19s |   -0.17492 |             0.7026 |             0.4098 |      2.8320 |            22.4191 |      0.8054 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171715863159
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.179105651063
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173598719912
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172364155302
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.178280800291
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175867597562
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.175163591367
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171597847928
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175726264136
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.176181478463
#
# Mean logloss for model in 10-folds SKF: 0.174960196918
#    29 | 05m11s |   -0.17496 |             0.6474 |             0.6707 |      2.5246 |             8.5185 |      0.8542 |
# Start training on fold: 1
# Start predicting...
# Final score for fold 1 : 0.171264798306
#
# Start training on fold: 2
# Start predicting...
# Final score for fold 2 : 0.178958061477
#
# Start training on fold: 3
# Start predicting...
# Final score for fold 3 : 0.173506310614
#
# Start training on fold: 4
# Start predicting...
# Final score for fold 4 : 0.172315379635
#
# Start training on fold: 5
# Start predicting...
# Final score for fold 5 : 0.177751862821
#
# Start training on fold: 6
# Start predicting...
# Final score for fold 6 : 0.175651806983
#
# Start training on fold: 7
# Start predicting...
# Final score for fold 7 : 0.174842816906
#
# Start training on fold: 8
# Start predicting...
# Final score for fold 8 : 0.171583071635
#
# Start training on fold: 9
# Start predicting...
# Final score for fold 9 : 0.175515248912
#
# Start training on fold: 10
# Start predicting...
# Final score for fold 10 : 0.17627173855
#
# Mean logloss for model in 10-folds SKF: 0.174766109584
#    30 | 05m48s |   -0.17477 |             0.6148 |             0.5127 |      4.1900 |             5.4381 |      0.8799 |
# lgb: -0.174744
