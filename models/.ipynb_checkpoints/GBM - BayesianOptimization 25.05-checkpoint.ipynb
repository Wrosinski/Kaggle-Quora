# %%
import gc
import time
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb

from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from bayes_opt import BayesianOptimization
from models_utils_fe import *
# Out:
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def xgb_bo(max_depth, min_child_weight, subsample, colsample_bytree):
    
    t = time.time()
    params = {
    'seed': 1337,
    'colsample_bytree': max(min(colsample_bytree, 1), 0),
    'silent': 1,
    'subsample': max(min(subsample, 1), 0),
    'eta': 0.05,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'max_depth': int(max_depth),
    'min_child_weight': int(min_child_weight),
    'nthread': 4,
    'tree_method': 'hist',
    }
    
    dtrain = xgb.DMatrix(X_tr, label = y_tr)
    dval = xgb.DMatrix(X_val, label = y_val)
    watchlist = [(dtrain, 'train'), (dval, 'valid')]

    print('Start training...')
    gbm = xgb.train(params, dtrain, 100000, watchlist, 
                    early_stopping_rounds = 100, verbose_eval = 100)
    val_pred = gbm.predict(xgb.DMatrix(X_val), ntree_limit=gbm.best_ntree_limit)
    score = log_loss(y_val, val_pred)
    print('Final score:', score, '\n', 'Time it took to train and predict:', time.time() - t)
    return -score


def lgb_bo(max_depth, min_data_in_leaf, subsample, colsample_bytree, feature_fraction):
    params = {
        'task' : 'train',
        'boosting_type' : 'gbdt',
        'objective' : 'binary',
        'metric' : {'binary_logloss'},
        'learning_rate' : 0.05,
        'feature_fraction' : max(min(feature_fraction, 1), 0),
        'bagging_fraction': 0.9,
        'bagging_freq': 100,
        'num_leaves' : 255,
        'max_depth': int(max_depth),
        'min_data_in_leaf': int(min_data_in_leaf),
        'subsample': max(min(subsample, 1), 0),
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'silent': 1,
        'random_state': 1337,
        'verbose': 1,
        'nthread': 9,
    }

    lgb_train = lgb.Dataset(X_tr, y_tr.is_duplicate.values)
    lgb_val = lgb.Dataset(X_val, y_val.is_duplicate.values)
    t = time.time()
    print('Start training...')
    gbm = lgb.train(params, lgb_train, num_boost_round = 100000, valid_sets = lgb_val,
                    early_stopping_rounds = 100, verbose_eval = 100)
    val_pred = gbm.predict(X_val, num_iteration=gbm.best_iteration)
    score = log_loss(y_val, val_pred)
    print('Final score:', score, '\n', 'Time it took to train and predict:', time.time() - t)
    return -score

# %%
src = '/media/w/1c392724-ecf3-4615-8f3c-79368ec36380/DS Projects/Kaggle/Quora/scripts/features/'
feats_src = '/media/w/1c392724-ecf3-4615-8f3c-79368ec36380/DS Projects/Kaggle/Quora/data/features/uncleaned/'

X_train = pd.read_pickle('Xtrain_825colsCurrentBest.pkl')
new_set = pd.read_pickle('train_NewSubset_BestAbhishek.pkl')
new_set.columns = ['{}_abhishek_new_lemmat'.format(i) for i in range(new_set.shape[1])]
new_network = pd.read_pickle('train_networkfeats_weighted_30.05.pkl')

xgb_feats = pd.read_csv(feats_src + '/the_1owl/owl_train.csv')
y_train = xgb_feats[['is_duplicate']]

for col in new_network.columns:
    X_train[col] = new_network[col]

X_train = pd.concat([X_train, new_set], axis = 1)
X_train = X_train.astype('float32')
print(X_train.shape)

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, stratify = y_train,
                                                    test_size = 0.2, random_state = 111)

del xgb_feats, new_set, new_network, X_train
gc.collect()
# Out:
# (404290, 905)
# 395

# %% [markdown]
# Step |   Time |      Value |   colsample_bytree |   feature_fraction |   max_depth |   min_data_in_leaf |   subsample |
#
# *  15 | 05m01s |   -0.18297 |             0.3500 |             0.5717 |      6.0000 |            27.8939 |      0.6900 |
# * 7 | 03m49s |   -0.18385 |             0.3641 |             0.4773 |      6.3882 |            20.4263 |      0.8623 |
# *  9 | 03m29s |   -0.18331 |             0.4370 |             0.5345 |      7.6824 |            16.8610 |      0.7681 |
# *    13 | 03m11s |   -0.18492 |             0.5000 |             0.5032 |     10.0000 |            27.9822 |      0.6900 |

# %%
lgbBO = BayesianOptimization(lgb_bo, {
        'max_depth': (6, 10),
        'min_data_in_leaf': (15, 28),
        'subsample': (0.69, 0.88),
        'colsample_bytree': (0.35, 0.5),
        'feature_fraction': (0.35, 0.65),
    })

num_iter = 15
init_points = 10
lgbBO.maximize(init_points=init_points, n_iter=num_iter)
print('lgb: %f' % lgbBO.res['max']['max_val'])
# Out:
# Initialization
# ------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   feature_fraction |   max_depth |   min_data_in_leaf |   subsample |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.229462
# [200]	valid_0's binary_logloss: 0.215266
# [300]	valid_0's binary_logloss: 0.209817
# [400]	valid_0's binary_logloss: 0.207121
# [500]	valid_0's binary_logloss: 0.205499
# [600]	valid_0's binary_logloss: 0.204589
# [700]	valid_0's binary_logloss: 0.203774
# [800]	valid_0's binary_logloss: 0.203344
# [900]	valid_0's binary_logloss: 0.203177
# [1000]	valid_0's binary_logloss: 0.202966
# [1100]	valid_0's binary_logloss: 0.203027
# Early stopping, best iteration is:
# [1048]	valid_0's binary_logloss: 0.202936
# Final score: 0.20296001502
#  Time it took to train and predict: 267.9007291793823
#     1 | 04m27s |   -0.20296 |             0.3900 |             0.4278 |      8.9310 |            24.4283 |      0.8510 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.197471
# [200]	valid_0's binary_logloss: 0.189391
# [300]	valid_0's binary_logloss: 0.187076
# [400]	valid_0's binary_logloss: 0.18602
# [500]	valid_0's binary_logloss: 0.185249
# [600]	valid_0's binary_logloss: 0.184877
# [700]	valid_0's binary_logloss: 0.184753
# [800]	valid_0's binary_logloss: 0.184516
# Early stopping, best iteration is:
# [775]	valid_0's binary_logloss: 0.184468
# Final score: 0.184471415732
#  Time it took to train and predict: 257.1586961746216
#     2 | 04m17s |   -0.18447 |             0.4784 |             0.5897 |      8.4423 |            16.8750 |      0.7246 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.234436
# [200]	valid_0's binary_logloss: 0.219111
# [300]	valid_0's binary_logloss: 0.212745
# [400]	valid_0's binary_logloss: 0.209595
# [500]	valid_0's binary_logloss: 0.207607
# [600]	valid_0's binary_logloss: 0.206116
# [700]	valid_0's binary_logloss: 0.204877
# [800]	valid_0's binary_logloss: 0.204144
# [900]	valid_0's binary_logloss: 0.20361
# [1000]	valid_0's binary_logloss: 0.203034
# [1100]	valid_0's binary_logloss: 0.202697
# [1200]	valid_0's binary_logloss: 0.202482
# [1300]	valid_0's binary_logloss: 0.202372
# [1400]	valid_0's binary_logloss: 0.202229
# [1500]	valid_0's binary_logloss: 0.202191
# Early stopping, best iteration is:
# [1428]	valid_0's binary_logloss: 0.202137
# Final score: 0.202145961372
#  Time it took to train and predict: 272.715039730072
#     3 | 04m32s |   -0.20215 |             0.3806 |             0.4266 |      7.9009 |            19.6576 |      0.8715 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.235227
# [200]	valid_0's binary_logloss: 0.219856
# [300]	valid_0's binary_logloss: 0.214418
# [400]	valid_0's binary_logloss: 0.211284
# [500]	valid_0's binary_logloss: 0.20953
# [600]	valid_0's binary_logloss: 0.208113
# [700]	valid_0's binary_logloss: 0.207141
# [800]	valid_0's binary_logloss: 0.206232
# [900]	valid_0's binary_logloss: 0.205471
# [1000]	valid_0's binary_logloss: 0.20482
# [1100]	valid_0's binary_logloss: 0.204712
# [1200]	valid_0's binary_logloss: 0.204286
# [1300]	valid_0's binary_logloss: 0.204091
# [1400]	valid_0's binary_logloss: 0.203974
# [1500]	valid_0's binary_logloss: 0.20388
# [1600]	valid_0's binary_logloss: 0.203747
# [1700]	valid_0's binary_logloss: 0.203922
# Early stopping, best iteration is:
# [1612]	valid_0's binary_logloss: 0.203703
# Final score: 0.203709096983
#  Time it took to train and predict: 284.0933074951172
#     4 | 04m44s |   -0.20371 |             0.3936 |             0.3706 |      7.3923 |            27.2443 |      0.8591 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.195859
# [200]	valid_0's binary_logloss: 0.188492
# [300]	valid_0's binary_logloss: 0.18623
# [400]	valid_0's binary_logloss: 0.185552
# [500]	valid_0's binary_logloss: 0.185364
# [600]	valid_0's binary_logloss: 0.185708
# Early stopping, best iteration is:
# [526]	valid_0's binary_logloss: 0.185233
# Final score: 0.185249685947
#  Time it took to train and predict: 247.64398455619812
#     5 | 04m07s |   -0.18525 |             0.4271 |             0.6216 |      9.9030 |            22.5497 |      0.8103 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.229967
# [200]	valid_0's binary_logloss: 0.216466
# [300]	valid_0's binary_logloss: 0.211324
# [400]	valid_0's binary_logloss: 0.208832
# [500]	valid_0's binary_logloss: 0.207226
# [600]	valid_0's binary_logloss: 0.206506
# [700]	valid_0's binary_logloss: 0.20591
# [800]	valid_0's binary_logloss: 0.205206
# [900]	valid_0's binary_logloss: 0.204961
# [1000]	valid_0's binary_logloss: 0.204932
# [1100]	valid_0's binary_logloss: 0.205251
# Early stopping, best iteration is:
# [1008]	valid_0's binary_logloss: 0.204886
# Final score: 0.20489251442
#  Time it took to train and predict: 241.0179557800293
#     6 | 04m01s |   -0.20489 |             0.3992 |             0.3603 |      8.7002 |            23.7623 |      0.8521 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.204655
# [200]	valid_0's binary_logloss: 0.193761
# [300]	valid_0's binary_logloss: 0.190362
# [400]	valid_0's binary_logloss: 0.188512
# [500]	valid_0's binary_logloss: 0.187148
# [600]	valid_0's binary_logloss: 0.186403
# [700]	valid_0's binary_logloss: 0.185898
# [800]	valid_0's binary_logloss: 0.185336
# [900]	valid_0's binary_logloss: 0.185062
# [1000]	valid_0's binary_logloss: 0.18485
# [1100]	valid_0's binary_logloss: 0.184803
# [1200]	valid_0's binary_logloss: 0.184592
# [1300]	valid_0's binary_logloss: 0.184361
# [1400]	valid_0's binary_logloss: 0.184058
# [1500]	valid_0's binary_logloss: 0.183961
# [1600]	valid_0's binary_logloss: 0.183877
# Early stopping, best iteration is:
# [1575]	valid_0's binary_logloss: 0.183839
# Final score: 0.183853079945
#  Time it took to train and predict: 229.6181981563568
#     7 | 03m49s |   -0.18385 |             0.3641 |             0.4773 |      6.3882 |            20.4263 |      0.8623 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.234699
# [200]	valid_0's binary_logloss: 0.219514
# [300]	valid_0's binary_logloss: 0.213605
# [400]	valid_0's binary_logloss: 0.210443
# [500]	valid_0's binary_logloss: 0.20859
# [600]	valid_0's binary_logloss: 0.207247
# [700]	valid_0's binary_logloss: 0.206226
# [800]	valid_0's binary_logloss: 0.205553
# [900]	valid_0's binary_logloss: 0.204789
# [1000]	valid_0's binary_logloss: 0.204263
# [1100]	valid_0's binary_logloss: 0.20407
# [1200]	valid_0's binary_logloss: 0.203897
# [1300]	valid_0's binary_logloss: 0.203681
# [1400]	valid_0's binary_logloss: 0.203336
# [1500]	valid_0's binary_logloss: 0.203119
# [1600]	valid_0's binary_logloss: 0.203027
# [1700]	valid_0's binary_logloss: 0.203118
# Early stopping, best iteration is:
# [1613]	valid_0's binary_logloss: 0.202967
# Final score: 0.202973305407
#  Time it took to train and predict: 280.0250768661499
#     8 | 04m40s |   -0.20297 |             0.3840 |             0.4150 |      7.6038 |            18.1435 |      0.7395 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.20026
# [200]	valid_0's binary_logloss: 0.190723
# [300]	valid_0's binary_logloss: 0.187621
# [400]	valid_0's binary_logloss: 0.18649
# [500]	valid_0's binary_logloss: 0.185363
# [600]	valid_0's binary_logloss: 0.184664
# [700]	valid_0's binary_logloss: 0.184122
# [800]	valid_0's binary_logloss: 0.18371
# [900]	valid_0's binary_logloss: 0.183434
# [1000]	valid_0's binary_logloss: 0.183372
# Early stopping, best iteration is:
# [978]	valid_0's binary_logloss: 0.183296
# Final score: 0.18331039705
#  Time it took to train and predict: 208.98831510543823
#     9 | 03m29s |   -0.18331 |             0.4370 |             0.5345 |      7.6824 |            16.8610 |      0.7681 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.195603
# [200]	valid_0's binary_logloss: 0.187868
# [300]	valid_0's binary_logloss: 0.185609
# [400]	valid_0's binary_logloss: 0.184853
# [500]	valid_0's binary_logloss: 0.184644
# Early stopping, best iteration is:
# [466]	valid_0's binary_logloss: 0.184432
# Final score: 0.18443798461
#  Time it took to train and predict: 188.7857644557953
#    10 | 03m08s |   -0.18444 |             0.4191 |             0.5459 |      9.9391 |            22.4966 |      0.7184 |
# Bayesian Optimization
# ------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   feature_fraction |   max_depth |   min_data_in_leaf |   subsample |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.203638
# [200]	valid_0's binary_logloss: 0.193272
# [300]	valid_0's binary_logloss: 0.189898
# [400]	valid_0's binary_logloss: 0.188192
# [500]	valid_0's binary_logloss: 0.187059
# [600]	valid_0's binary_logloss: 0.186354
# [700]	valid_0's binary_logloss: 0.185854
# [800]	valid_0's binary_logloss: 0.185209
# [900]	valid_0's binary_logloss: 0.184843
# [1000]	valid_0's binary_logloss: 0.18452
# [1100]	valid_0's binary_logloss: 0.184436
# [1200]	valid_0's binary_logloss: 0.184115
# [1300]	valid_0's binary_logloss: 0.184029
# [1400]	valid_0's binary_logloss: 0.183934
# [1500]	valid_0's binary_logloss: 0.183799
# [1600]	valid_0's binary_logloss: 0.183774
# [1700]	valid_0's binary_logloss: 0.183602
# [1800]	valid_0's binary_logloss: 0.183614
# Early stopping, best iteration is:
# [1725]	valid_0's binary_logloss: 0.183554
# Final score: 0.183558190505
#  Time it took to train and predict: 308.3738079071045
#    11 | 05m33s |   -0.18356 |             0.5000 |             0.6500 |      6.0000 |            15.0000 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.194748
# [200]	valid_0's binary_logloss: 0.187469
# [300]	valid_0's binary_logloss: 0.185529
# [400]	valid_0's binary_logloss: 0.185133
# [500]	valid_0's binary_logloss: 0.185155
# Early stopping, best iteration is:
# [484]	valid_0's binary_logloss: 0.185036
# Final score: 0.18504063797
#  Time it took to train and predict: 252.62506866455078
#    12 | 04m26s |   -0.18504 |             0.3500 |             0.6500 |     10.0000 |            15.0000 |      0.8800 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.195656
# [200]	valid_0's binary_logloss: 0.187945
# [300]	valid_0's binary_logloss: 0.185894
# [400]	valid_0's binary_logloss: 0.185158
# [500]	valid_0's binary_logloss: 0.185147
# Early stopping, best iteration is:
# [463]	valid_0's binary_logloss: 0.184907
# Final score: 0.184918643377
#  Time it took to train and predict: 174.54247450828552
#    13 | 03m11s |   -0.18492 |             0.5000 |             0.5032 |     10.0000 |            27.9822 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.203646
# [200]	valid_0's binary_logloss: 0.193482
# [300]	valid_0's binary_logloss: 0.190212
# [400]	valid_0's binary_logloss: 0.188626
# [500]	valid_0's binary_logloss: 0.187493
# [600]	valid_0's binary_logloss: 0.186725
# [700]	valid_0's binary_logloss: 0.186046
# [800]	valid_0's binary_logloss: 0.185532
# [900]	valid_0's binary_logloss: 0.18505
# [1000]	valid_0's binary_logloss: 0.184733
# [1100]	valid_0's binary_logloss: 0.184526
# [1200]	valid_0's binary_logloss: 0.184344
# [1300]	valid_0's binary_logloss: 0.184204
# [1400]	valid_0's binary_logloss: 0.184052
# Early stopping, best iteration is:
# [1386]	valid_0's binary_logloss: 0.184027
# Final score: 0.18403975467
#  Time it took to train and predict: 254.25833654403687
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 50, 'grad': array([ -3.55774153e-05])}
#   " state: %s" % convergence_dict)
#    14 | 04m32s |   -0.18404 |             0.4478 |             0.6500 |      6.0000 |            23.1621 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.20374
# [200]	valid_0's binary_logloss: 0.193147
# [300]	valid_0's binary_logloss: 0.189679
# [400]	valid_0's binary_logloss: 0.18791
# [500]	valid_0's binary_logloss: 0.186757
# [600]	valid_0's binary_logloss: 0.186008
# [700]	valid_0's binary_logloss: 0.185528
# [800]	valid_0's binary_logloss: 0.18508
# [900]	valid_0's binary_logloss: 0.184623
# [1000]	valid_0's binary_logloss: 0.184278
# [1100]	valid_0's binary_logloss: 0.183954
# [1200]	valid_0's binary_logloss: 0.183776
# [1300]	valid_0's binary_logloss: 0.183621
# [1400]	valid_0's binary_logloss: 0.183493
# [1500]	valid_0's binary_logloss: 0.183369
# [1600]	valid_0's binary_logloss: 0.183244
# [1700]	valid_0's binary_logloss: 0.183016
# [1800]	valid_0's binary_logloss: 0.18304
# Early stopping, best iteration is:
# [1756]	valid_0's binary_logloss: 0.182959
# Final score: 0.18297093543
#  Time it took to train and predict: 283.0075914859772
#    15 | 05m01s |   -0.18297 |             0.3500 |             0.5717 |      6.0000 |            27.8939 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.200338
# [200]	valid_0's binary_logloss: 0.19123
# [300]	valid_0's binary_logloss: 0.188211
# [400]	valid_0's binary_logloss: 0.186806
# [500]	valid_0's binary_logloss: 0.185634
# [600]	valid_0's binary_logloss: 0.184991
# [700]	valid_0's binary_logloss: 0.184586
# [800]	valid_0's binary_logloss: 0.18411
# [900]	valid_0's binary_logloss: 0.183985
# [1000]	valid_0's binary_logloss: 0.183819
# [1100]	valid_0's binary_logloss: 0.183816
# Early stopping, best iteration is:
# [1018]	valid_0's binary_logloss: 0.183739
# Final score: 0.183746124108
#  Time it took to train and predict: 253.51436853408813
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 56, 'grad': array([ -4.17465072e-05])}
#   " state: %s" % convergence_dict)
#    16 | 04m34s |   -0.18375 |             0.4136 |             0.6500 |      7.9793 |            15.0000 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.203513
# [200]	valid_0's binary_logloss: 0.193349
# [300]	valid_0's binary_logloss: 0.190083
# [400]	valid_0's binary_logloss: 0.18833
# [500]	valid_0's binary_logloss: 0.187327
# [600]	valid_0's binary_logloss: 0.186565
# [700]	valid_0's binary_logloss: 0.186077
# [800]	valid_0's binary_logloss: 0.185408
# [900]	valid_0's binary_logloss: 0.185005
# [1000]	valid_0's binary_logloss: 0.184704
# [1100]	valid_0's binary_logloss: 0.18448
# [1200]	valid_0's binary_logloss: 0.184336
# [1300]	valid_0's binary_logloss: 0.18407
# [1400]	valid_0's binary_logloss: 0.183954
# [1500]	valid_0's binary_logloss: 0.183879
# [1600]	valid_0's binary_logloss: 0.183644
# [1700]	valid_0's binary_logloss: 0.183391
# [1800]	valid_0's binary_logloss: 0.183428
# Early stopping, best iteration is:
# [1700]	valid_0's binary_logloss: 0.183391
# Final score: 0.183385277445
#  Time it took to train and predict: 297.3173735141754
#    17 | 05m19s |   -0.18339 |             0.4803 |             0.6301 |      6.0251 |            17.1496 |      0.6916 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.20362
# [200]	valid_0's binary_logloss: 0.19315
# [300]	valid_0's binary_logloss: 0.189809
# [400]	valid_0's binary_logloss: 0.188093
# [500]	valid_0's binary_logloss: 0.18694
# [600]	valid_0's binary_logloss: 0.186085
# [700]	valid_0's binary_logloss: 0.185558
# [800]	valid_0's binary_logloss: 0.185035
# [900]	valid_0's binary_logloss: 0.18458
# [1000]	valid_0's binary_logloss: 0.184187
# [1100]	valid_0's binary_logloss: 0.183985
# [1200]	valid_0's binary_logloss: 0.183783
# [1300]	valid_0's binary_logloss: 0.183583
# [1400]	valid_0's binary_logloss: 0.183508
# [1500]	valid_0's binary_logloss: 0.183425
# [1600]	valid_0's binary_logloss: 0.183473
# Early stopping, best iteration is:
# [1543]	valid_0's binary_logloss: 0.183379
# Final score: 0.183386505194
#  Time it took to train and predict: 281.78644943237305
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 52, 'grad': array([ -2.97586374e-05])}
#   " state: %s" % convergence_dict)
#    18 | 05m03s |   -0.18339 |             0.5000 |             0.6500 |      6.0000 |            20.9712 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.195858
# [200]	valid_0's binary_logloss: 0.188324
# [300]	valid_0's binary_logloss: 0.186144
# [400]	valid_0's binary_logloss: 0.185509
# [500]	valid_0's binary_logloss: 0.185388
# Early stopping, best iteration is:
# [467]	valid_0's binary_logloss: 0.185218
# Final score: 0.185232922101
#  Time it took to train and predict: 219.10521030426025
#    19 | 04m05s |   -0.18523 |             0.3500 |             0.6500 |     10.0000 |            18.0077 |      0.8800 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.240768
# [200]	valid_0's binary_logloss: 0.224385
# [300]	valid_0's binary_logloss: 0.218325
# [400]	valid_0's binary_logloss: 0.214758
# [500]	valid_0's binary_logloss: 0.212582
# [600]	valid_0's binary_logloss: 0.210846
# [700]	valid_0's binary_logloss: 0.209855
# [800]	valid_0's binary_logloss: 0.208768
# [900]	valid_0's binary_logloss: 0.207788
# [1000]	valid_0's binary_logloss: 0.20697
# [1100]	valid_0's binary_logloss: 0.206373
# [1200]	valid_0's binary_logloss: 0.205903
# [1300]	valid_0's binary_logloss: 0.20564
# [1400]	valid_0's binary_logloss: 0.205183
# [1500]	valid_0's binary_logloss: 0.204899
# [1600]	valid_0's binary_logloss: 0.204613
# [1700]	valid_0's binary_logloss: 0.204428
# Early stopping, best iteration is:
# [1699]	valid_0's binary_logloss: 0.204426
# Final score: 0.204430843885
#  Time it took to train and predict: 210.50309038162231
#    20 | 03m51s |   -0.20443 |             0.3500 |             0.3500 |      6.0000 |            15.6589 |      0.8800 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.203692
# [200]	valid_0's binary_logloss: 0.193401
# [300]	valid_0's binary_logloss: 0.190024
# [400]	valid_0's binary_logloss: 0.188379
# [500]	valid_0's binary_logloss: 0.187309
# [600]	valid_0's binary_logloss: 0.186355
# [700]	valid_0's binary_logloss: 0.185877
# [800]	valid_0's binary_logloss: 0.185246
# [900]	valid_0's binary_logloss: 0.184764
# [1000]	valid_0's binary_logloss: 0.184548
# [1100]	valid_0's binary_logloss: 0.184348
# [1200]	valid_0's binary_logloss: 0.184095
# [1300]	valid_0's binary_logloss: 0.183989
# [1400]	valid_0's binary_logloss: 0.183886
# [1500]	valid_0's binary_logloss: 0.183728
# [1600]	valid_0's binary_logloss: 0.183695
# [1700]	valid_0's binary_logloss: 0.183484
# [1800]	valid_0's binary_logloss: 0.183591
# Early stopping, best iteration is:
# [1700]	valid_0's binary_logloss: 0.183484
# Final score: 0.183485393286
#  Time it took to train and predict: 307.0395631790161
#    21 | 05m25s |   -0.18349 |             0.3553 |             0.6500 |      6.0206 |            25.4412 |      0.6908 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.194723
# [200]	valid_0's binary_logloss: 0.187566
# [300]	valid_0's binary_logloss: 0.185936
# [400]	valid_0's binary_logloss: 0.185322
# [500]	valid_0's binary_logloss: 0.185795
# Early stopping, best iteration is:
# [418]	valid_0's binary_logloss: 0.18522
# Final score: 0.185229211542
#  Time it took to train and predict: 226.3331482410431
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 51, 'grad': array([  2.67354005e-05])}
#   " state: %s" % convergence_dict)
#    22 | 04m07s |   -0.18523 |             0.3500 |             0.6500 |     10.0000 |            20.7424 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.203607
# [200]	valid_0's binary_logloss: 0.193478
# [300]	valid_0's binary_logloss: 0.19006
# [400]	valid_0's binary_logloss: 0.188297
# [500]	valid_0's binary_logloss: 0.187312
# [600]	valid_0's binary_logloss: 0.186553
# [700]	valid_0's binary_logloss: 0.185877
# [800]	valid_0's binary_logloss: 0.185356
# [900]	valid_0's binary_logloss: 0.18485
# [1000]	valid_0's binary_logloss: 0.184662
# [1100]	valid_0's binary_logloss: 0.184533
# [1200]	valid_0's binary_logloss: 0.184389
# [1300]	valid_0's binary_logloss: 0.184221
# [1400]	valid_0's binary_logloss: 0.184077
# [1500]	valid_0's binary_logloss: 0.183962
# Early stopping, best iteration is:
# [1493]	valid_0's binary_logloss: 0.183933
# Final score: 0.183937515463
#  Time it took to train and predict: 272.5420994758606
#    23 | 04m55s |   -0.18394 |             0.3500 |             0.6500 |      6.0009 |            19.8422 |      0.6932 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.194858
# [200]	valid_0's binary_logloss: 0.187551
# [300]	valid_0's binary_logloss: 0.185665
# [400]	valid_0's binary_logloss: 0.185075
# [500]	valid_0's binary_logloss: 0.185499
# Early stopping, best iteration is:
# [410]	valid_0's binary_logloss: 0.185012
# Final score: 0.185022927369
#  Time it took to train and predict: 222.81728768348694
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:308: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
#    24 | 04m05s |   -0.18502 |             0.5000 |             0.6500 |     10.0000 |            16.4653 |      0.6900 |
# Start training...
# Train until valid scores didn't improve in 100 rounds.
# [100]	valid_0's binary_logloss: 0.194892
# [200]	valid_0's binary_logloss: 0.187571
# [300]	valid_0's binary_logloss: 0.185677
# [400]	valid_0's binary_logloss: 0.185158
# Early stopping, best iteration is:
# [375]	valid_0's binary_logloss: 0.185003
# Final score: 0.185006663093
#  Time it took to train and predict: 206.67720913887024
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 7, 'warnflag': 2, 'funcalls': 62, 'grad': array([ -2.94212186e-05])}
#   " state: %s" % convergence_dict)
#    25 | 03m49s |   -0.18501 |             0.3500 |             0.6500 |     10.0000 |            26.4377 |      0.7411 |
# lgb: -0.182971

# %% [markdown]
# Step |   Time |      Value |   colsample_bytree |   max_depth |   min_child_weight |   subsample |
#
# * 2 | 27m56s |   -0.18223 |             0.4418 |      6.6308 |            21.9368 |      0.8242 |
# * 16 | 26m18s |   -0.18250 |             0.4628 |      7.6076 |            21.3771 |      0.8899 |
# * 13 | 32m26s |   -0.18254 |             0.4265 |      5.0034 |            29.9491 |      0.8833 |

# %%
xgbBO = BayesianOptimization(xgb_bo, {
        'max_depth': (5, 10),
        'min_child_weight': (15, 30),
        'subsample': (0.69, 0.89),
        'colsample_bytree': (0.35, 0.47),
    })

num_iter = 15
init_points = 10
xgbBO.maximize(init_points=init_points, n_iter=num_iter)
print('XGB: %f' % xgbBO.res['max']['max_val'])
# Out:
# Initialization
# ---------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |   colsample_bytree |   max_depth |   min_child_weight |   subsample |
# Start training...
# [0]	train-logloss:0.662004	valid-logloss:0.662131
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.202054	valid-logloss:0.206741
# [200]	train-logloss:0.188426	valid-logloss:0.19542
# [300]	train-logloss:0.181745	valid-logloss:0.191759
# [400]	train-logloss:0.176674	valid-logloss:0.189656
# [500]	train-logloss:0.172359	valid-logloss:0.188406
# [600]	train-logloss:0.168297	valid-logloss:0.187367
# [700]	train-logloss:0.164542	valid-logloss:0.186715
# [800]	train-logloss:0.161137	valid-logloss:0.186278
# [900]	train-logloss:0.157914	valid-logloss:0.18587
# [1000]	train-logloss:0.154678	valid-logloss:0.1855
# [1100]	train-logloss:0.151625	valid-logloss:0.18518
# [1200]	train-logloss:0.148876	valid-logloss:0.185027
# [1300]	train-logloss:0.146137	valid-logloss:0.184795
# [1400]	train-logloss:0.143252	valid-logloss:0.184599
# [1500]	train-logloss:0.140499	valid-logloss:0.184394
# [1600]	train-logloss:0.138019	valid-logloss:0.184134
# [1700]	train-logloss:0.135457	valid-logloss:0.18398
# [1800]	train-logloss:0.132951	valid-logloss:0.183806
# [1900]	train-logloss:0.130592	valid-logloss:0.183747
# [2000]	train-logloss:0.128405	valid-logloss:0.183712
# [2100]	train-logloss:0.126226	valid-logloss:0.183608
# [2200]	train-logloss:0.124033	valid-logloss:0.18355
# [2300]	train-logloss:0.121904	valid-logloss:0.183478
# [2400]	train-logloss:0.119905	valid-logloss:0.183505
# Stopping. Best iteration:
# [2328]	train-logloss:0.121314	valid-logloss:0.183456
#
# Final score: 0.183455895657
#  Time it took to train and predict: 1752.4059154987335
#     1 | 29m12s |   -0.18346 |             0.4567 |      5.2883 |            26.4571 |      0.8717 |
# Start training...
# [0]	train-logloss:0.661236	valid-logloss:0.661408
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.196031	valid-logloss:0.202277
# [200]	train-logloss:0.181929	valid-logloss:0.192371
# [300]	train-logloss:0.173106	valid-logloss:0.189059
# [400]	train-logloss:0.16649	valid-logloss:0.187444
# [500]	train-logloss:0.160623	valid-logloss:0.186419
# [600]	train-logloss:0.15518	valid-logloss:0.185658
# [700]	train-logloss:0.149785	valid-logloss:0.185179
# [800]	train-logloss:0.145049	valid-logloss:0.184688
# [900]	train-logloss:0.14056	valid-logloss:0.18426
# [1000]	train-logloss:0.136032	valid-logloss:0.183838
# [1100]	train-logloss:0.131736	valid-logloss:0.183513
# [1200]	train-logloss:0.127633	valid-logloss:0.183285
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 4, 'warnflag': 2, 'funcalls': 52, 'grad': array([ -2.12292855e-05])}
#   " state: %s" % convergence_dict)
#    16 | 26m18s |   -0.18250 |             0.4628 |      7.6076 |            21.3771 |      0.8899 |
# Start training...
# [0]	train-logloss:0.659632	valid-logloss:0.659947
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.180555	valid-logloss:0.195828
# [200]	train-logloss:0.16003	valid-logloss:0.188378
# [300]	train-logloss:0.144983	valid-logloss:0.186472
# [400]	train-logloss:0.132435	valid-logloss:0.185505
# [500]	train-logloss:0.121353	valid-logloss:0.184938
# [600]	train-logloss:0.11137	valid-logloss:0.18452
# [700]	train-logloss:0.102301	valid-logloss:0.184222
# [800]	train-logloss:0.094101	valid-logloss:0.184079
# [900]	train-logloss:0.086669	valid-logloss:0.184021
# Stopping. Best iteration:
# [846]	train-logloss:0.090633	valid-logloss:0.183941
#
# Final score: 0.183941080747
#  Time it took to train and predict: 1020.3468532562256
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 48, 'grad': array([-0.00010911])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 53, 'grad': array([-0.00026049])}
#   " state: %s" % convergence_dict)
#    17 | 17m19s |   -0.18394 |             0.4687 |      9.9157 |            20.3852 |      0.7002 |
# Start training...
# [0]	train-logloss:0.660494	valid-logloss:0.660711
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.190369	valid-logloss:0.199296
# [200]	train-logloss:0.173984	valid-logloss:0.190199
# [300]	train-logloss:0.162828	valid-logloss:0.187574
# [400]	train-logloss:0.153707	valid-logloss:0.186074
# [500]	train-logloss:0.145494	valid-logloss:0.185099
# [600]	train-logloss:0.13751	valid-logloss:0.184489
# [700]	train-logloss:0.130566	valid-logloss:0.183958
# [800]	train-logloss:0.124212	valid-logloss:0.183666
# [900]	train-logloss:0.118497	valid-logloss:0.183261
# [1000]	train-logloss:0.112517	valid-logloss:0.183066
# [1100]	train-logloss:0.107478	valid-logloss:0.182876
# [1200]	train-logloss:0.102424	valid-logloss:0.182744
# Stopping. Best iteration:
# [1175]	train-logloss:0.103686	valid-logloss:0.182693
#
# Final score: 0.18269293721
#  Time it took to train and predict: 1220.4313888549805
#    18 | 20m38s |   -0.18269 |             0.4687 |      7.7112 |            17.5822 |      0.8794 |
# Start training...
# [0]	train-logloss:0.661251	valid-logloss:0.66141
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.196345	valid-logloss:0.2024
# [200]	train-logloss:0.182259	valid-logloss:0.192669
# [300]	train-logloss:0.174247	valid-logloss:0.189522
# [400]	train-logloss:0.167772	valid-logloss:0.187808
# [500]	train-logloss:0.161932	valid-logloss:0.186689
# [600]	train-logloss:0.15647	valid-logloss:0.185879
# [700]	train-logloss:0.151562	valid-logloss:0.185192
# [800]	train-logloss:0.146845	valid-logloss:0.184747
# [900]	train-logloss:0.140537	valid-logloss:0.184495
# [1000]	train-logloss:0.136146	valid-logloss:0.184104
# [1100]	train-logloss:0.131982	valid-logloss:0.18388
# [1200]	train-logloss:0.12808	valid-logloss:0.183505
# [1300]	train-logloss:0.124092	valid-logloss:0.183285
# [1400]	train-logloss:0.120179	valid-logloss:0.183087
# [1500]	train-logloss:0.116499	valid-logloss:0.182973
# [1600]	train-logloss:0.11337	valid-logloss:0.182856
# [1700]	train-logloss:0.109972	valid-logloss:0.182694
# [1800]	train-logloss:0.10676	valid-logloss:0.182619
# [1900]	train-logloss:0.103657	valid-logloss:0.182507
# [2000]	train-logloss:0.100899	valid-logloss:0.182467
# [2100]	train-logloss:0.098112	valid-logloss:0.182394
# [2200]	train-logloss:0.095482	valid-logloss:0.18238
# [2300]	train-logloss:0.092649	valid-logloss:0.182373
# [2400]	train-logloss:0.090136	valid-logloss:0.182336
# Stopping. Best iteration:
# [2316]	train-logloss:0.092253	valid-logloss:0.18231
#
# Final score: 0.182309632168
#  Time it took to train and predict: 1923.1065011024475
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 58, 'grad': array([ -5.80670239e-05])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 49, 'grad': array([-0.00049482])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 54, 'grad': array([ 0.00094715])}
#   " state: %s" % convergence_dict)
#    21 | 32m19s |   -0.18231 |             0.4683 |      6.7427 |            22.0700 |      0.8571 |
# Start training...
# [0]	train-logloss:0.660634	valid-logloss:0.660823
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.191396	valid-logloss:0.200003
# [200]	train-logloss:0.175335	valid-logloss:0.190649
# [300]	train-logloss:0.164973	valid-logloss:0.187919
# [400]	train-logloss:0.156727	valid-logloss:0.186663
# [500]	train-logloss:0.149041	valid-logloss:0.185778
# [600]	train-logloss:0.142401	valid-logloss:0.184934
# [700]	train-logloss:0.135871	valid-logloss:0.184579
# [800]	train-logloss:0.129967	valid-logloss:0.184099
# [900]	train-logloss:0.123997	valid-logloss:0.183753
# [1000]	train-logloss:0.118844	valid-logloss:0.183553
# [1100]	train-logloss:0.113403	valid-logloss:0.183381
# [1200]	train-logloss:0.10861	valid-logloss:0.183247
# [1300]	train-logloss:0.104034	valid-logloss:0.183131
# [1400]	train-logloss:0.099868	valid-logloss:0.182994
# [1500]	train-logloss:0.095396	valid-logloss:0.182894
# [1600]	train-logloss:0.091453	valid-logloss:0.182938
# Stopping. Best iteration:
# [1572]	train-logloss:0.092558	valid-logloss:0.182857
#
# Final score: 0.182857409633
#  Time it took to train and predict: 1454.8704874515533
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 4, 'warnflag': 2, 'funcalls': 51, 'grad': array([-0.00150254])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 4, 'warnflag': 2, 'funcalls': 54, 'grad': array([ 0.00521081])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 68, 'grad': array([ -9.51974703e-05])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 2, 'warnflag': 2, 'funcalls': 49, 'grad': array([-0.00144258])}
#   " state: %s" % convergence_dict)
#    22 | 24m33s |   -0.18286 |             0.3528 |      7.1260 |            22.0360 |      0.7892 |
# Start training...
# [0]	train-logloss:0.661255	valid-logloss:0.661417
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 72, 'grad': array([ -9.60469251e-05])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 82, 'grad': array([ -4.26065599e-05])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 53, 'grad': array([ -6.13161023e-05])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 3, 'warnflag': 2, 'funcalls': 63, 'grad': array([-0.00116522])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 6, 'warnflag': 2, 'funcalls': 64, 'grad': array([-0.0008574])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 5, 'warnflag': 2, 'funcalls': 67, 'grad': array([  1.36138206e-05])}
#   " state: %s" % convergence_dict)
#    24 | 26m03s |   -0.18379 |             0.4551 |      5.5275 |            22.2331 |      0.6914 |
# Start training...
# [0]	train-logloss:0.662006	valid-logloss:0.662132
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 100 rounds.
# [100]	train-logloss:0.202068	valid-logloss:0.20679
# [200]	train-logloss:0.188119	valid-logloss:0.1953
# [300]	train-logloss:0.181256	valid-logloss:0.191731
# [400]	train-logloss:0.176116	valid-logloss:0.18977
# [500]	train-logloss:0.17155	valid-logloss:0.188407
# [600]	train-logloss:0.16718	valid-logloss:0.187388
# [700]	train-logloss:0.163424	valid-logloss:0.186672
# [800]	train-logloss:0.159783	valid-logloss:0.186218
# [900]	train-logloss:0.156275	valid-logloss:0.185652
# [1000]	train-logloss:0.152981	valid-logloss:0.185349
# [1100]	train-logloss:0.149868	valid-logloss:0.185089
# [1200]	train-logloss:0.146899	valid-logloss:0.184807
# [1300]	train-logloss:0.144039	valid-logloss:0.18458
# [1400]	train-logloss:0.141053	valid-logloss:0.184357
# [1500]	train-logloss:0.138343	valid-logloss:0.184161
# [1600]	train-logloss:0.135676	valid-logloss:0.183989
# [1700]	train-logloss:0.133105	valid-logloss:0.183743
# [1800]	train-logloss:0.130585	valid-logloss:0.183491
# [1900]	train-logloss:0.128084	valid-logloss:0.183432
# [2000]	train-logloss:0.125742	valid-logloss:0.183322
# [2100]	train-logloss:0.123335	valid-logloss:0.183207
# [2200]	train-logloss:0.121142	valid-logloss:0.183097
# [2300]	train-logloss:0.118705	valid-logloss:0.183033
# [2400]	train-logloss:0.116527	valid-logloss:0.18301
# Stopping. Best iteration:
# [2347]	train-logloss:0.117658	valid-logloss:0.18297
#
# Final score: 0.182970176344
#  Time it took to train and predict: 1747.9312953948975
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 3, 'warnflag': 2, 'funcalls': 50, 'grad': array([-0.00198629])}
#   " state: %s" % convergence_dict)
# /home/w/anaconda3/envs/idp3/lib/python3.5/site-packages/sklearn/gaussian_process/gpr.py:427: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'nit': 4, 'warnflag': 2, 'funcalls': 57, 'grad': array([-0.00620399])}
#   " state: %s" % convergence_dict)
#    25 | 29m28s |   -0.18297 |             0.3941 |      5.4764 |            16.5597 |      0.8856 |
# XGB: -0.182231
